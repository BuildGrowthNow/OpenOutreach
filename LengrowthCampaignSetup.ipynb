# %% [markdown]
# # LenGrowth Campaign Setup for OpenOutreach
#
# This notebook helps you configure the LenGrowth campaign parameters for OpenOutreach.
#
# ## What This Does
#
# 1. Sets up your product description for LenGrowth
# 2. Configures the campaign objective
# 3. Pre-fills relevant search keywords
# 4. Sets up a default booking link
#
# ## Prerequisites
#
# 1. OpenOutreach is running (Docker or local)
# 2. You have Django admin access
# 3. You have an admin user created

# %% [markdown]
# ## Step 1: Configure Your Details

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# YOUR CONFIGURATION - FILL IN THESE VALUES
═══════════════════════════════════════════════════════════════════════════════

# Your booking/demo link (where leads can schedule a meeting)
YOUR_BOOKING_LINK = "https://calendly.com/yourcompany/lengrowth-demo"

# Your name/brand for the outreach
YOUR_NAME = "[Your Name]"
YOUR_BRAND = "LenGrowth"

# Company description (optional, overrides default)
YOUR_COMPANY_DESC = """
LenGrowth is a comprehensive growth operating system that bridges the gap between high-level growth strategy and daily task execution.

We help growth teams orchestrate a three-tier execution model involving Humans, AI Agents, and Domain Experts to drive measurable business growth.
"""

# %% [markdown]
# ## Step 2: Define Your Ideal Customer Profile
#
# The system will use these definitions to qualifies leads.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# IDEAL CUSTOMER PROFILE
═══════════════════════════════════════════════════════════════════════════════

IDEAL_CUSTOMER = {
    "primary_targets": [
        "Founders",
        "Co-Founders",
        "CEOs",
        "Heads of Growth",
        "Growth Managers",
        "Marketing Directors",
        "VP of Growth"
    ],
    "secondary_targets": [
        "Marketing Managers",
        "Digital Marketing Managers",
        "Performance Marketing Managers",
        "Conversion Rate Optimization Leads",
        "Business Development Managers"
    ],
    "ideal_industries": [
        "SaaS",
        "B2B Technology",
        "Ecommerce",
        "Digital Agencies",
        "Marketing Agencies"
    ],
    "company_sizes": [
        "1-10 employees - early stage startups",
        "11-50 employees - scaling startups",
        "51-200 employees - established growth teams"
    ],
    "tech_stacks": [
        "FastAPI",
        "MongoDB",
        "Next.js",
        "Python",
        "Docker",
        "AI/ML tools"
    ],
    "pain_points": [
        "Need for better growth strategy",
        "Difficulty scaling execution",
        "Lack of unified growth platform",
        "Manual processes slowing growth",
        "Need AI-assisted execution"
    ]
}

print("Ideal Customer Profile configured:")
for category, items in IDEAL_CUSTOMER.items():
    print(f"  [OK] {category}:")
    for item in items:
        print(f"    - {item}")

# %% [markdown]
# ## Step 3: Pre-Configure Search Keywords
#
# Run this to add relevant keywords to your campaign.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# SEARCH KEYWORDS
═══════════════════════════════════════════════════════════════════════════════

SEARCH_KEYWORDS = {
    "job_titles": [
        "Founder", "Co-Founder", "CEO", "CTO", "CMO",
        "Head of Growth", "Head of Marketing", "VP of Growth",
        "Growth Lead", "Growth Manager", "Growth Strategist",
        "Director of Marketing", "Marketing Manager",
        "Digital Marketing Manager", "Performance Marketing Manager",
        "Conversion Rate Optimization Lead", "Product Growth Manager",
        "Customer Success Manager", "Sales Operations Manager",
        "Business Development Manager", "Startup Founder",
        "Entrepreneur", "Small Business Owner"
    ],
    "interests": [
        "Growth Hacking", "SaaS", "B2B Marketing", "B2C Marketing",
        "Digital Marketing", "Marketing Automation", "Lead Generation",
        "Customer Acquisition", "Conversion Optimization", "Analytics",
        "Data-Driven Marketing", "ABM", "Content Marketing",
        "Email Marketing", "SEO/SEM", "LinkedIn Marketing",
        "Growth Platforms", "AI for Marketing", "MarTech",
        "Revenue Operations", "RevOps"
    ],
    "pain_points": [
        "growing my business", "scaling my startup", "improving conversion",
        "increasing pipeline", "growth strategy", "marketing automation",
        "lead generation", "customer acquisition", "growth hacking",
        "B2B sales", "pipeline growth", "conversion rate",
        "ROI optimization", "growth platform", "AI growth tools"
    ],
    "company_signals": [
        "Series A company", "Series B startup", "Series C startup",
        "scaling fast", "high growth", "rapid growth",
        "exponential growth", "growth phase"
    ]
}

total_keywords = sum(len(v) for v in SEARCH_KEYWORDS.values())
print(f"Pre-configured {total_keywords} keywords across {len(SEARCH_KEYWORDS)} categories:")
for category, keywords in SEARCH_KEYWORDS.items():
    print(f"  {category}: {len(keywords)} keywords")

# %% [markdown]
# ## Step 4: Create Campaign Documents
#
# These are the official LenGrowth campaign definitions.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# PRODUCT DESCRIPTION
═══════════════════════════════════════════════════════════════════════════════

PRODUCT_DESCRIPTION = """
LenGrowth is a comprehensive growth operating system that bridges the gap between high-level growth strategy and daily task execution.

We help growth teams orchestrate a three-tier execution model involving Humans, AI Agents, and Domain Experts to drive measurable business growth.

CORE CAPABILITIES:
1. Strategic Alignment - Every task directly contributes to a Macro Objective
2. Hybrid Execution - Blending automated AI insights with expert-led execution
3. Enterprise Ready - Security (RBAC), scalability (Celery/Redis), API-first

KEY FEATURES:
- Execution Pipeline with real-time collaboration
- Strategy Command Center for growth planning
- Growth Trees for visualizing growth initiatives
- Advanced Task Engine with AI-assisted completion
- Assets Hub for generating reusable business documents
- Powerful Reporting dashboards
- AI Agent orchestration
- RBAC security controls

IDEAL FOR:
- Founders building growth systems
- Growth Managers needing structure
- Marketing Directors scaling campaigns
- Agencies managing multiple client accounts
- Teams needing unified strategy-to-execution platform

TECH STACK INTEGRATION:
FastAPI, MongoDB, Next.js, Python, Docker, AI/ML tools
"""

print(f"Product Description Created ({len(PRODUCT_DESCRIPTION)} characters)")

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# CAMPAIGN OBJECTIVE
═══════════════════════════════════════════════════════════════════════════════

CAMPAIGN_OBJECTIVE = """
Campaign Goal: Secure qualified leads for LenGrowth

Primary Objective:
Demonstrate our value as a comprehensive growth operating system that bridges
strategy and execution, converting discovered leads into booked discovery calls.

Target Audience:
- Founders and Growth Operators at scaling startups
- Marketing Leaders at mid-market companies
- Agency Directors managing multiple clients
- Business Development leaders seeking better processes

Success Criteria:
1. High-quality connection requests (40%+ acceptance rate)
2. Engaged follow-up conversations (20-30% response rate)
3. Booked discovery calls (5-10% conversion)
4. Long-term fit identification (qualifying bad leads quickly)

What We Will NOT Do:
- Spam or aggressive selling
- Contact inappropriate accounts (large enterprises, job seekers)
- Make unrealistic claims or promises
- Ignore follow-up frequency limits
"""

print("Campaign Objective Created")

# %% [markdown]
# ## Step 5: Quick Start Guide for User
#
# Copy and paste these steps when you first run OpenOutreach.

# %%
# ═══════════════════════════════════════════════════════════════════════════════
# QUICK START INSTRUCTIONS
═══════════════════════════════════════════════════════════════════════════════

QUICK_START_INSTRUCTIONS = """
================================================================================
                    LENGROWTH OPENOUTREACH SETUP CHECKLIST                    
================================================================================

STEP 1: Create .env File
──────────────────────────────────────────────────────────────────────────────
1. Copy .env.example to .env
2. Open .env and fill in:
   - LLM_API_KEY=sk-your-openai-api-key
   - AI_MODEL=gpt-4o
   - LINKEDIN_USERNAME=your-email@example.com
   - LINKEDIN_PASSWORD=your-password

STEP 2: Run OpenOutreach
──────────────────────────────────────────────────────────────────────────────
   docker run --pull always -it \\
     -p 5900:5900 \\
     -p 6080:6080 \\
     -v ~/.openoutreach/data:/app/data \\
     -v "$(pwd)/.env":/app/.env \\
     ghcr.io/eracle/openoutreach:latest

STEP 3: Access the Web Interface
──────────────────────────────────────────────────────────────────────────────
   Open: http://localhost:6080/vnc.html

STEP 4: Complete Onboarding Wizard
──────────────────────────────────────────────────────────────────────────────
When prompted, provide:

Product Description: (COPY from PRODUCT_DESCRIPTION cell above)

Campaign Objective: (COPY from CAMPAIGN_OBJECTIVE cell above)

Booking Link: (paste your link - e.g., https://calendly.com/...)

STEP 5: Monitor Your Campaign
──────────────────────────────────────────────────────────────────────────────
  - Check browser window for automation progress
  - Review Django Admin at :8000/admin/ for details
  - Adjust keywords if needed (LinkedIn > Search Keywords)
  - Monitor rate limits (LinkedIn > LinkedIn Profile)

═══════════════════════════════════════════════════════════════════════════════

QUICK TIPS:
  - Start with low limits (5 connections/day) for testing
  - Review qualified leads daily and adjust as needed
  - Personal follow-up messages get better responses
  - Be patient - quality leads take time to discover
  - Use Django Admin to edit campaigns and track progress

═══════════════════════════════════════════════════════════════════════════════
"""

print(QUICK_START_INSTRUCTIONS)

# %% [markdown]
# ## Next Steps
#
# 1. **Review the generated documentation** in `openoutreach/docs/`:
#    - `lengrowth_campaign.md` - Detailed campaign strategy
#    - `SETUP_GUIDE.md` - Complete setup instructions
#    - `README.md` - Original OpenOutreach documentation
#
# 2. **Create your `.env` file** with your API keys and LinkedIn credentials
#
# 3. **Run the Docker container** or use local installation
#
# 4. **Complete the onboarding wizard** with the values above
#
# 5. **Start monitoring** and adjust as needed
#
# ---
#
# *This notebook is designed to work alongside the OpenOutreach tool for LenGrowth. All configuration values are stored in the `.env` file and persisted in the SQLite database.*
